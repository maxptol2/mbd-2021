# %%
#!pip install skranger
# !pip install xgboost
# !pip install pyspark
# !pip install plotly
# !pip install folium
from xgboost import XGBClassifier
import sys
import folium
import json
import requests
import os
import matplotlib.pyplot as plt
from datetime import datetime as dt
from datetime import timedelta as td
from dateutil.relativedelta import relativedelta as rt
import pyspark
import pandas as pd
from plotly import graph_objects as go
import numpy as np
import seaborn as sns
plt.style.use('ggplot')
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
# Out:
# Requirement already satisfied: xgboost in c:\programdata\anaconda3\lib\site-packages (1.4.2)
# Requirement already satisfied: scipy in c:\programdata\anaconda3\lib\site-packages (from xgboost) (1.2.1)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from xgboost) (1.16.4)
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# WARNING: Ignoring invalid distribution -mportlib-metadata (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mportlib-metadata (c:\programdata\anaconda3\lib\site-packages)
# WARNING: You are using pip version 21.1.3; however, version 21.2.4 is available.
# You should consider upgrading via the 'C:\ProgramData\Anaconda3\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: pyspark in c:\programdata\anaconda3\lib\site-packages (2.4.3)
# Requirement already satisfied: py4j==0.10.7 in c:\programdata\anaconda3\lib\site-packages (from pyspark) (0.10.7)
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# WARNING: Ignoring invalid distribution -mportlib-metadata (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mportlib-metadata (c:\programdata\anaconda3\lib\site-packages)
# WARNING: You are using pip version 21.1.3; however, version 21.2.4 is available.
# You should consider upgrading via the 'C:\ProgramData\Anaconda3\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: plotly in c:\programdata\anaconda3\lib\site-packages (4.14.3)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from plotly) (1.12.0)
# Requirement already satisfied: retrying>=1.3.3 in c:\programdata\anaconda3\lib\site-packages (from plotly) (1.3.3)
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# WARNING: Ignoring invalid distribution -mportlib-metadata (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mportlib-metadata (c:\programdata\anaconda3\lib\site-packages)
# WARNING: You are using pip version 21.1.3; however, version 21.2.4 is available.
# You should consider upgrading via the 'C:\ProgramData\Anaconda3\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: folium in c:\programdata\anaconda3\lib\site-packages (0.12.1)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from folium) (2.22.0)
# Requirement already satisfied: branca>=0.3.0 in c:\programdata\anaconda3\lib\site-packages (from folium) (0.4.2)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from folium) (1.16.4)
# Requirement already satisfied: jinja2>=2.9 in c:\programdata\anaconda3\lib\site-packages (from folium) (2.10.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\programdata\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->folium) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->folium) (2019.6.16)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->folium) (1.24.2)
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# WARNING: Ignoring invalid distribution -mportlib-metadata (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mportlib-metadata (c:\programdata\anaconda3\lib\site-packages)
# WARNING: You are using pip version 21.1.3; however, version 21.2.4 is available.
# You should consider upgrading via the 'C:\ProgramData\Anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
datatrain_muestra_500=pd.read_csv('C:/Users/Maximiliano/Documents/Big_Data/TESIS_DE_MAESTRIA/Repositorio/mbd-2021-1/data/datasets/datatrain_muestra_500.csv', header=0)
datatrain_muestra_300=pd.read_csv('C:/Users/Maximiliano/Documents/Big_Data/TESIS_DE_MAESTRIA/Repositorio/mbd-2021-1/data/datasets/datatrain_muestra_300.csv', header=0)
datatrain_muestra_200=pd.read_csv('C:/Users/Maximiliano/Documents/Big_Data/TESIS_DE_MAESTRIA/Repositorio/mbd-2021-1/data/datasets/datatrain_muestra_200.csv', header=0)
datatrain_muestra_100=pd.read_csv('C:/Users/Maximiliano/Documents/Big_Data/TESIS_DE_MAESTRIA/Repositorio/mbd-2021-1/data/datasets/datatrain_muestra_100.csv', header=0)

dataval_muestra_250=pd.read_csv('C:/Users/Maximiliano/Documents/Big_Data/TESIS_DE_MAESTRIA/Repositorio/mbd-2021-1/data/datasets/dataval_muestra_250.csv', header=0)
dataval_muestra_150=pd.read_csv('C:/Users/Maximiliano/Documents/Big_Data/TESIS_DE_MAESTRIA/Repositorio/mbd-2021-1/data/datasets/dataval_muestra_150.csv', header=0)
dataval_muestra_100=pd.read_csv('C:/Users/Maximiliano/Documents/Big_Data/TESIS_DE_MAESTRIA/Repositorio/mbd-2021-1/data/datasets/dataval_muestra_100.csv', header=0)
dataval_muestra_50=pd.read_csv('C:/Users/Maximiliano/Documents/Big_Data/TESIS_DE_MAESTRIA/Repositorio/mbd-2021-1/data/datasets/dataval_muestra_50.csv', header=0)

datatest_muestra_210=pd.read_csv('C:/Users/Maximiliano/Documents/Big_Data/TESIS_DE_MAESTRIA/Repositorio/mbd-2021-1/data/datasets/datatest_muestra_210.csv', header=0)
datatest_muestra_120=pd.read_csv('C:/Users/Maximiliano/Documents/Big_Data/TESIS_DE_MAESTRIA/Repositorio/mbd-2021-1/data/datasets/datatest_muestra_120.csv', header=0)
datatest_muestra_90=pd.read_csv('C:/Users/Maximiliano/Documents/Big_Data/TESIS_DE_MAESTRIA/Repositorio/mbd-2021-1/data/datasets/datatest_muestra_90.csv', header=0)
datatest_muestra_32=pd.read_csv('C:/Users/Maximiliano/Documents/Big_Data/TESIS_DE_MAESTRIA/Repositorio/mbd-2021-1/data/datasets/datatest_muestra_32.csv', header=0)

# %%
X_cols = ['merchant','amt','zip',
          'job','Hora','Edad', 'category_food_dining', 
          'category_gas_transport','category_grocery_net','category_grocery_pos',
          'category_health_fitness','category_home','category_kids_pets','category_misc_net',
          'category_misc_pos','category_personal_care','category_shopping_net','category_shopping_pos',
          'category_travel','gender_M','week_Monday','week_Saturday','week_Sunday','week_Thursday',
          'week_Tuesday','week_Wednesday', 'dist', 'hist_trans_60d','hist_trans_24h','hist_fraud_trans_24h','hist_trans_amt_avg_60d']

Y_cols = ['is_fraud']

# %%
X_train_500 = datatrain_muestra_500[X_cols]
y_train_500 = datatrain_muestra_500[Y_cols]
X_val_250 = dataval_muestra_250[X_cols]
y_val_250 = dataval_muestra_250[Y_cols]
X_test_210 = datatest_muestra_210[X_cols]
y_test_210 = datatest_muestra_210[Y_cols]

# %%
X_train_300 = datatrain_muestra_300[X_cols]
y_train_300 = datatrain_muestra_300[Y_cols]
X_val_150 = dataval_muestra_150[X_cols]
y_val_150 = dataval_muestra_150[Y_cols]
X_test_120 = datatest_muestra_120[X_cols]
y_test_120 = datatest_muestra_120[Y_cols]

# %%
X_train_200 = datatrain_muestra_200[X_cols]
y_train_200 = datatrain_muestra_200[Y_cols]
X_val_100 = dataval_muestra_100[X_cols]
y_val_100 = dataval_muestra_100[Y_cols]
X_test_90 = datatest_muestra_90[X_cols]
y_test_90 = datatest_muestra_90[Y_cols]

# %%
X_train_100 = datatrain_muestra_100[X_cols]
y_train_100 = datatrain_muestra_100[Y_cols]
X_val_50 = dataval_muestra_50[X_cols]
y_val_50 = dataval_muestra_50[Y_cols]
X_test_32 = datatest_muestra_32[X_cols]
y_test_32 = datatest_muestra_32[Y_cols]

# %%
import sklearn
from sklearn.utils import class_weight
def class_weights(df, class_name) :
    y = df[class_name]
    return sklearn.utils.class_weight.compute_class_weight('balanced', np.unique(y), y)

# %%
import keras.models
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten
from keras.optimizers import SGD, Adam
import tensorflow as tf
from keras.activations import *
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.utils import class_weight
import numpy
import keras_metrics
import utils
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Fija las semillas aleatorias para la reproducibilidad
# numpy.random.seed(7)
#
#
# def Red_neuronal(neurons, dropout_rate, learn_rate):
#     # create model
#     model = Sequential()
#     model.add(Dense(neurons, input_dim=31, activation='relu'))
#     model.add(Dropout(dropout_rate))
#     model.add(Dense(3, activation='relu'))
#     model.add(Dense(1,activation='sigmoid'))
#     # Compile model
#     adam = Adam(lr=learn_rate)
#     model.compile(loss='binary_crossentropy', optimizer=adam, metrics=['accuracy'])
#     return model
#
# # create model
# model = KerasClassifier(build_fn=Red_neuronal)
#
# # define the grid search parameters
# batch_size = [250, 350]
# epochs = [50, 150, 300]
# learn_rate = [0.001, 0.01]
# dropout_rate = [0.0, 0.2, 0.5]
# neurons = [3, 12, 15]
#
# param_grid = dict(batch_size=batch_size,
#                   epochs=epochs,
#                   learn_rate=learn_rate,
#                   neurons=neurons,
#                   dropout_rate=dropout_rate)
#
# grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=3)

# %%
# Ajusta el modelo
#Ajuste_500 = grid.fit(X_train_500, y_train_500, class_weight = class_weights(datatrain_muestra_500, 'is_fraud'), validation_data=(X_val_250,y_val_250))
#Ajuste_300 = grid.fit(X_train_300, y_train_300, class_weight = class_weights(datatrain_muestra_300, 'is_fraud'), validation_data=(X_val_150,y_val_150))
#Ajuste_200 = grid.fit(X_train_200, y_train_200, class_weight = class_weights(datatrain_muestra_200, 'is_fraud'), validation_data=(X_val_100,y_val_100))
#Ajuste_100 = grid.fit(X_train_100, y_train_100, class_weight = class_weights(datatrain_muestra_100, 'is_fraud'), validation_data=(X_val_50,y_val_50))

# %%
#print("Best: %f using %s" % (Ajuste_500.best_score_, Ajuste_500.best_params_))
#print("Best: %f using %s" % (Ajuste_300.best_score_, Ajuste_300.best_params_))
#print("Best: %f using %s" % (Ajuste_200.best_score_, Ajuste_200.best_params_))
#print("Best: %f using %s" % (Ajuste_100.best_score_, Ajuste_100.best_params_))

# %%
numpy.random.seed(7)

# crea el modelo
model = Sequential()
model.add(Dense(15, input_dim=31, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(3, activation='relu'))
model.add(Dense(1, activation='sigmoid'))


# Compila el modelo
adam=Adam(lr=0.001)


model.compile(loss='binary_crossentropy', optimizer=adam, metrics=[keras_metrics.precision(), keras_metrics.recall()])

# Ajusta el modelo
history = model.fit(X_train_500, 
                    y_train_500, 
                    epochs=150, 
                    batch_size=250, 
                    class_weight = class_weights(datatrain_muestra_500, 'is_fraud'), 
                    validation_data=(X_val_250,y_val_250))
# Out:
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# C:\Users\Maximiliano\AppData\Roaming\Python\Python37\site-packages\sklearn\utils\validation.py:72: FutureWarning: Pass classes=[0 1], y=0         0
# 1         0
# 2         1
# 3         0
# 4         1
# 5         0
# 6         1
# 7         0
# 8         1
# 9         0
# 10        0
# 11        0
# 12        0
# 13        0
# 14        1
# 15        0
# 16        0
# 17        0
# 18        1
# 19        0
# 20        0
# 21        0
# 22        1
# 23        0
# 24        0
# 25        1
# 26        0
# 27        0
# 28        0
# 29        0
#          ..
# 499970    0
# 499971    0
# 499972    0
# 499973    0
# 499974    0
# 499975    1
# 499976    0
# 499977    0
# 499978    0
# 499979    0
# 499980    0
# 499981    0
# 499982    0
# 499983    0
# 499984    0
# 499985    0
# 499986    0
# 499987    1
# 499988    1
# 499989    0
# 499990    1
# 499991    1
# 499992    0
# 499993    0
# 499994    0
# 499995    1
# 499996    0
# 499997    0
# 499998    1
# 499999    0
# Name: is_fraud, Length: 500000, dtype: int64 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   "will result in an error", FutureWarning)
# Train on 500000 samples, validate on 250000 samples
# Epoch 1/150
# 500000/500000 [==============================] - 3s 7us/step - loss: 0.9081 - precision: 0.2350 - recall: 0.0031 - val_loss: 0.5482 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/150
# 500000/500000 [==============================] - 3s 6us/step - loss: 0.5477 - precision: 0.2167 - recall: 1.0989e-04 - val_loss: 0.5479 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/150
# 500000/500000 [==============================] - 3s 6us/step - loss: 0.5471 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.5479 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/150
# 500000/500000 [==============================] - 4s 7us/step - loss: 0.5471 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.5479 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/150
# 500000/500000 [==============================] - 5s 10us/step - loss: 0.5470 - precision: 0.7500 - recall: 5.8324e-04 - val_loss: 0.5479 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/150
# 500000/500000 [==============================] - 6s 11us/step - loss: 0.4574 - precision: 0.9140 - recall: 0.2924 - val_loss: 0.3131 - val_precision: 0.9309 - val_recall: 0.5874
# Epoch 7/150
# 500000/500000 [==============================] - 5s 10us/step - loss: 0.3641 - precision: 0.9099 - recall: 0.5293 - val_loss: 0.2904 - val_precision: 0.9292 - val_recall: 0.6397
# Epoch 8/150
# 500000/500000 [==============================] - 5s 10us/step - loss: 0.3265 - precision: 0.9055 - recall: 0.6137 - val_loss: 0.2019 - val_precision: 0.9405 - val_recall: 0.8142
# Epoch 9/150
# 500000/500000 [==============================] - 5s 10us/step - loss: 0.3241 - precision: 0.9028 - recall: 0.6304 - val_loss: 0.2822 - val_precision: 0.9163 - val_recall: 0.7266
# Epoch 10/150
# 500000/500000 [==============================] - 5s 9us/step - loss: 0.3208 - precision: 0.9028 - recall: 0.6363 - val_loss: 0.1528 - val_precision: 0.9403 - val_recall: 0.8944
# Epoch 11/150
# 500000/500000 [==============================] - 4s 8us/step - loss: 0.3114 - precision: 0.9200 - recall: 0.6406 - val_loss: 0.1907 - val_precision: 0.9403 - val_recall: 0.8554
# Epoch 12/150
# 500000/500000 [==============================] - 4s 7us/step - loss: 0.3192 - precision: 0.9254 - recall: 0.6189 - val_loss: 0.1537 - val_precision: 0.9495 - val_recall: 0.9003
# Epoch 13/150
# 500000/500000 [==============================] - 4s 7us/step - loss: 0.3163 - precision: 0.9289 - recall: 0.6186 - val_loss: 0.1098 - val_precision: 0.9576 - val_recall: 0.9462
# Epoch 14/150
# 500000/500000 [==============================] - 4s 7us/step - loss: 0.2977 - precision: 0.9334 - recall: 0.6560 - val_loss: 0.1618 - val_precision: 0.9680 - val_recall: 0.8893
# Epoch 15/150
# 500000/500000 [==============================] - 4s 7us/step - loss: 0.2847 - precision: 0.9413 - recall: 0.6699 - val_loss: 0.1466 - val_precision: 0.9608 - val_recall: 0.9366
# Epoch 16/150
# 500000/500000 [==============================] - 4s 7us/step - loss: 0.3080 - precision: 0.9588 - recall: 0.6060 - val_loss: 0.1098 - val_precision: 0.9871 - val_recall: 0.9227
# Epoch 17/150
# 500000/500000 [==============================] - 4s 7us/step - loss: 0
150
# 500000/500000 [==============================] - 4s 7us/step - loss: 0.1672 - precision: 0.9973 - recall: 0.8190 - val_loss: 0.0499 - val_precision: 0.9997 - val_recall: 0.9999
# Epoch 100/150
# 500000/500000 [==============================] - 4s 7us/step - loss: 0.2593 - precision: 0.9928 - recall: 0.6679 - val_loss: 0.1004 - val_precision: 0.9990 - val_recall: 0.9998
# Epoch 101/150
# 500000/500000 [==============================] - 4s 7us/step - loss: 0.1481 - precision: 0.9959 - recall: 0.8410 - val_loss: 0.0167 - val_precision: 0.9995 - val_recall: 0.9999
# Epoch 102/150
# 500000/500000 [==============================] - 4s 7us/step - loss: 0.2334 - precision: 0.9913 - recall: 0.7057 - val_loss: 0.0503 - val_precision: 0.9938 - val_recall: 0.9994
# Epoch 103/150
# 500000/500000 [==============================] - 4s 7us/step - loss: 0.1666 - precision: 0.9964 - recall: 0.8153 - val_loss: 0.0943 - val_precision: 0.9989 - val_recall: 0.9999
# Epoch 104/150
# 500000/500000 [==============================] - 4s 7us/step - loss: 0.1729 - precision: 0.9963 - recall: 0.8098 - val_loss: 0.0270 - val_precision: 0.9997 - val_recall: 0.9999
# Epoch 105/150
# 500000/500000 [==============================] - 4s 7us/step - loss: 0.1681 - precision: 0.9973 - recall: 0.8179 - val_loss: 0.0512 - val_precision: 0.9987 - val_recall: 0.9999
# Epoch 106/150
# 500000/500000 [==============================] - 4s 7us/step - loss: 0.1769 - precision: 0.9937 - recall: 0.8050 - val_loss: 0.0264 - val_precision: 0.9993 - val_recall: 0.9999
# Epoch 107/150
# 500000/500000 [==============================] - 4s 7us/step - loss: 0.2609 - precision: 0.9906 - recall: 0.6696 - val_loss: 0.0524 - val_precision: 0.9989 - val_recall: 0.9999
# Epoch 108/150
# 500000/500000 [==============================] - 4s 7us/step - loss: 0.1631 - precision: 0.9937 - recall: 0.8290 - val_loss: 0.0400 - val_precision: 0.9992 - val_recall: 0.9999
# Epoch 109/150
# 500000/500000 [==============================] - 4s 7us/step - loss: 0.2003 - precision: 0.9963 - recall: 0.7653 - val_loss: 0.0649 - val_precision: 0.9969 - val_recall: 0.9999
# Epoch 110/150
# 500000/500000 [==============================] - 4s 7us/step - loss: 0.1926 - precision: 0.9953 - recall: 0.7827 - val_loss: 0.0485 - val_precision: 0.9980 - val_recall: 0.9999
# Epoch 111/150
# 500000/500000 [==============================] - 4s 7us/step - loss: 0.1751 - precision: 0.9957 - recall: 0.8049 - val_loss: 0.0275 - val_precision: 0.9995 - val_recall: 0.9999
# Epoch 112/150
# 500000/500000 [==============================] - 4s 7us/step - loss: 0.2641 - precision: 0.9889 - recall: 0.6402 - val_loss: 0.0304 - val_precision: 0.9982 - val_recall: 0.9999
# Epoch 113/150
# 500000/500000 [==============================] - 4s 7us/step - loss: 0.1649 - precision: 0.9967 - recall: 0.8179 - val_loss: 0.0252 - val_precision: 0.9953 - val_recall: 0.9999
# Epoch 114/150
# 500000/500000 [==============================] - 4s 7us/step - loss: 0.2078 - precision: 0.9961 - recall: 0.7523 - val_loss: 0.0890 - val_precision: 0.9827 - val_recall: 0.9999
# Epoch 115/150
# 500000/500000 [==============================] - 4s 7us/step - loss: 0.1241 - precision: 0.9964 - recall: 0.8775 - val_loss: 0.0170 - val_precision: 0.9998 - val_recall: 0.9999
# Epoch 116/150
# 500000/500000 [==============================] - 4s 7us/step - loss: 0.2461 - precision: 0.9942 - recall: 0.6816 - val_loss: 0.0504 - val_precision: 0.9895 - val_recall: 0.9993
# Epoch 117/150
# 500000/500000 [==============================] - 4s 7us/step - loss: 0.1614 - precision: 0.9936 - recall: 0.8300 - val_loss: 0.0344 - val_precision: 0.9993 - val_recall: 0.9999
# Epoch 118/150
# 500000/500000 [==============================] - 4s 7us/step - loss: 0.2174 - precision: 0.9942 - recall: 0.7204 - val_loss: 0.0345 - val_precision: 0.9991 - val_recall: 0.9999
# Epoch 119/150
# 500000/500000 [==============================] - 4s 7us/step - loss: 0.1661 - precision: 0.9964 - recall: 0.8181 - val_loss: 0.0335 - val_precision: 0.9996 - val_recall: 0.9999
# Epoch 120/150
# 500000/500000 [==============================] - 4s 7us/step - loss: 0.1734 - precision: 0.9960 - recall: 0.8118 - val_loss: 0.0314 - val_precision: 0.9978 - val_recall: 0.9999
# Epoch 121/150
# 500000/500000 [==============================] - 4s 7us/step - loss: 0.1726 - precision: 0.9950 - recall: 0.8059 - val_loss: 0.0228 - val_precision: 0.9994 - val_recall: 0.9999
# Epoch 122/150
# 500000/500000 [==============================] - 4s 7us/step - loss: 0.1307 - precision: 0.9983 - recall: 0.8681 - val_loss: 0.0170 - val_precision: 0.9988 - val_recall: 0.9999
# Epoch 123/150
# 500000/500000 [==============================] - 4s 7us/step - loss: 0.1952 - precision: 0.9940 - recall: 0.7778 - val_loss: 0.0306 - val_precision: 0.9976 - val_recall: 0.9999
# Epoch 124/150
# 500000/500000 [==============================] - 4s 7us/step - loss: 0.2013 - precision: 0.9957 - recall: 0.7490 - val_loss: 0.0511 - val_precision: 0.9995 - val_recall: 0.9999
# Epoch 125/150
# 500000/500000 [==============================] - 4s 7us/step - loss: 0.1431 - precision: 0.9981 - recall: 0.8533 - val_loss: 0.0276 - val_precision: 0.9992 - val_recall: 0.9999
# Epoch 126/150
# 500000/500000 [==============================] - 4s 7us/step - loss: 0.2118 - precision: 0.9930 - recall: 0.7465 - val_loss: 0.0513 - val_precision: 0.9994 - val_recall: 0.9999
# Epoch 127/150
# 500000/500000 [==============================] - 4s 7us/step - loss: 0.1642 - precision: 0.9967 - recall: 0.8205 - val_loss: 0.0274 - val_precision: 0.9971 - val_recall: 0.9999
# Epoch 128/150
# 500000/500000 [==============================] - 4s 7us/step - loss: 0.1054 - precision: 0.9990 - recall: 0.9005 - val_loss: 0.0269 - val_precision: 0.9999 - val_recall: 0.9999
# Epoch 129/150
# 500000/500000 [==============================] - 4s 8us/step - loss: 0.2405 - precision: 0.9941 - recall: 0.6971 - val_loss: 0.0972 - val_precision: 0.9989 - val_recall: 0.9999
# Epoch 130/150
# 500000/500000 [==============================] - 4s 8us/step - loss: 0.1849 - precision: 0.9951 - recall: 0.7940 - val_loss: 0.0315 - val_precision: 0.9992 - val_recall: 0.9999
# Epoch 131/150
# 500000/500000 [==============================] - 4s 8us/step - loss: 0.1481 - precision: 0.9972 - recall: 0.8435 - val_loss: 0.0532 - val_precision: 0.9998 - val_recall: 0.9999
# Epoch 132/150
# 500000/500000 [==============================] - 4s 8us/step - loss: 0.2347 - precision: 0.9959 - recall: 0.7137 - val_loss: 0.0668 - val_precision: 0.9859 - val_recall: 0.9999
# Epoch 133/150
# 500000/500000 [==============================] - 4s 8us/step - loss: 0.1417 - precision: 0.9985 - recall: 0.8550 - val_loss: 0.0264 - val_precision: 0.9979 - val_recall: 0.9999
# Epoch 134/150
# 500000/500000 [==============================] - 4s 9us/step - loss: 0.1851 - precision: 0.9960 - recall: 0.7878 - val_loss: 0.0353 - val_precision: 0.9993 - val_recall: 0.9999
# Epoch 135/150
# 500000/500000 [==============================] - 5s 9us/step - loss: 0.1628 - precision: 0.9968 - recall: 0.8258 - val_loss: 0.0277 - val_precision: 0.9997 - val_recall: 0.9999
# Epoch 136/150
# 500000/500000 [==============================] - 5s 9us/step - loss: 0.1149 - precision: 0.9990 - recall: 0.8892 - val_loss: 0.0167 - val_precision: 0.9999 - val_recall: 0.9999
# Epoch 137/150
# 500000/500000 [==============================] - 5s 9us/step - loss: 0.2219 - precision: 0.9949 - recall: 0.7209 - val_loss: 0.0306 - val_precision: 0.9991 - val_recall: 0.9999
# Epoch 138/150
# 500000/500000 [==============================] - 5s 10us/step - loss: 0.1382 - precision: 0.9986 - recall: 0.8597 - val_loss: 0.0277 - val_precision: 0.9998 - val_recall: 0.9999
# Epoch 139/150
# 500000/500000 [==============================] - 5s 10us/step - loss: 0.1559 - precision: 0.9972 - recall: 0.8338 - val_loss: 0.0296 - val_precision: 0.9998 - val_recall: 0.9999
# Epoch 140/150
# 500000/500000 [==============================] - 5s 9us/step - loss: 0.1904 - precision: 0.9954 - recall: 0.7739 - val_loss: 0.0474 - val_precision: 0.9972 - val_recall: 0.9999
# Epoch 141/150
# 500000/500000 [==============================] - 4s 9us/step - loss: 0.1174 - precision: 0.9972 - recall: 0.8851 - val_loss: 0.0185 - val_precision: 0.9998 - val_recall: 0.9999
# Epoch 142/150
# 500000/500000 [==============================] - 4s 9us/step - loss: 0.1966 - precision: 0.9962 - recall: 0.7620 - val_loss: 0.0962 - val_precision: 0.9987 - val_recall: 0.9950
# Epoch 143/150
# 500000/500000 [==============================] - 4s 9us/step - loss: 0.1537 - precision: 0.9976 - recall: 0.8346 - val_loss: 0.0152 - val_precision: 0.9999 - val_recall: 0.9999
# Epoch 144/150
# 500000/500000 [==============================] - 4s 9us/step - loss: 0.1335 - precision: 0.9981 - recall: 0.8606 - val_loss: 0.1009 - val_precision: 0.9997 - val_recall: 0.9141
# Epoch 145/150
# 500000/500000 [==============================] - 4s 9us/step - loss: 0.1621 - precision: 0.9966 - recall: 0.8099 - val_loss: 0.0270 - val_precision: 1.0000 - val_recall: 0.9999
# Epoch 146/150
# 500000/500000 [==============================] - 4s 9us/step - loss: 0.1463 - precision: 0.9986 - recall: 0.8445 - val_loss: 0.0536 - val_precision: 0.9993 - val_recall: 0.9999
# Epoch 147/150
# 500000/500000 [==============================] - 4s 9us/step - loss: 0.1170 - precision: 0.9984 - recall: 0.8846 - val_loss: 0.0491 - val_precision: 0.9999 - val_recall: 0.9999
# Epoch 148/150
# 500000/500000 [==============================] - 4s 9us/step - loss: 0.2358 - precision: 0.9954 - recall: 0.7106 - val_loss: 0.0523 - val_precision: 1.0000 - val_recall: 0.9999
# Epoch 149/150
# 500000/500000 [==============================] - 4s 8us/step - loss: 0.1646 - precision: 0.9987 - recall: 0.8224 - val_loss: 0.0268 - val_precision: 0.9999 - val_recall: 0.9999
# Epoch 150/150
# 500000/500000 [==============================] - 4s 8us/step - loss: 0.1170 - precision: 0.9986 - recall: 0.8876 - val_loss: 0.0176 - val_precision: 0.9986 - val_recall: 0.9999

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
# calcula las predicciones
predictions = model.predict(X_test_210)

# redondeamos las predicciones
rounded = [round(x[0]) for x in predictions]
#print(rounded)

# %%
utils.eval_model(history, model, X_test_210, y_test_210, 'is_fraud')

# %%
print(classification_report(y_test_210, rounded))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    209189
#            1       0.89      1.00      0.94       811
#
#     accuracy                           1.00    210000
#    macro avg       0.94      1.00      0.97    210000
# weighted avg       1.00      1.00      1.00    210000

# %%
utils.plot_cm(y_test_210, predictions)

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 15)                480
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 15)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 48
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 4
# =================================================================
# Total params: 532
# Trainable params: 532
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Guardar el Modelo
model.save('ANN.h5')

# %%
#Alta de Modelo
import keras.models
alta_modelo = keras.models.load_model('ANN.h5', compile=False)
alta_modelo.compile(loss='binary_crossentropy', optimizer=adam, metrics=[keras_metrics.precision(), keras_metrics.recall()])

# %%
# calcula las predicciones para 120000 datos
predictions_120 = alta_modelo.predict(X_test_120)
predictions_90 = alta_modelo.predict(X_test_90)
predictions_32 = alta_modelo.predict(X_test_32)

# redondeamos las predicciones
rounded_120 = [round(x[0]) for x in predictions_120]
rounded_90 = [round(x[0]) for x in predictions_90]
rounded_32 = [round(x[0]) for x in predictions_32]

# %%
print(classification_report(y_test_120, rounded_120))
print(classification_report(y_test_90, rounded_90))
print(classification_report(y_test_32, rounded_32))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    119545
#            1       0.89      1.00      0.94       455
#
#     accuracy                           1.00    120000
#    macro avg       0.94      1.00      0.97    120000
# weighted avg       1.00      1.00      1.00    120000
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     89650
#            1       0.89      1.00      0.94       350
#
#     accuracy                           1.00     90000
#    macro avg       0.95      1.00      0.97     90000
# weighted avg       1.00      1.00      1.00     90000
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     31887
#            1       0.90      1.00      0.95       113
#
#     accuracy                           1.00     32000
#    macro avg       0.95      1.00      0.97     32000
# weighted avg       1.00      1.00      1.00     32000

# %%
utils.plot_cm(y_test_120, predictions_120)
utils.plot_cm(y_test_90, predictions_90)
utils.plot_cm(y_test_32, predictions_32)
